# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Unicorn_Companies (2).csv')

# %%
df
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
mapper = {'Date Joined': 'Date_joined', 'Year Founded': 'Year_Founded', 'Select Investors': 'Select_Investors'}
df.rename(columns=mapper, inplace = True)

# %%
df
# Out:
#           Company Valuation Date_joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year_Founded Funding  \
# ...

# %%
df.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date_joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year_Founded         0
# Funding              0
# Select_Investors     1
# dtype: int64

# %%
df[df.City.isna()]
# Out:
#                          Company Valuation Date_joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# 1061                       WeLab       $1B  2017-11-08
#
# ...

# %%
df[df.Select_Investors.isna()]
# Out:
#               Company Valuation Date_joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year_Founded Funding Select_Investors
# 629  Shanghai   China      Asia          2013    $52M              NaN

# %%
df['Select_Investors'].value_counts()
# Out:
# Select_Investors
# Sequoia Capital                                             3
# Pelion Venture Partners, Foundation Capital, Thoma Bravo    2
# Insight Partners, Sequoia Capital, Index Ventures           2
# Speedinvest, Valar Ventures, Uniqa Ventures                 2
# SoftBank Group                                              2
#                                                            ..
# Trustbridge Partners, IDG Capital, Sequoia Capital China    1
# K2VC, Lightspeed China Partners, Sky9 Capital               1
# Automobile Industry Guidance Fund                           1
# Trustbridge Partners, Hony Capital, IDG Capital             1
# Novator Partners, True, Causeway Media Partners             1
# Name: count, Length: 1058, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
#                 ...
# Santa Barbara      1
# Altrincham         1
# Northbrook         1
# Cincinnati         1
# Milpitas           1
# Name: count, Length: 256, dtype: int64

# %%
df.fillna({'City': 'Unknown', 'Select_Investors': 'Unknown'}, inplace = True)

# %%
df[df['City'] == 'Unknown']
# Out:
#                          Company Valuation Date_joined  \
# 12                           FTX      $32B  2021-07-20
# 170                    HyalRoute       $4B  2020-05-26
# 242                       Moglix       $3B  2021-05-17
# 251                         Trax       $3B  2019-07-22
# 325                  Amber Group       $3B  2021-06-21
# 382                    Ninja Van       $2B  2021-09-27
# 541   Advance Intelligence Group       $2B  2021-09-23
# 811                    Carousell       $1B  2021-09-15
# 848                   Matrixport       $1B  2021-06-01
# 880                     bolttech       $1B  2021-07-01
# 889                        Carro       $1B  2021-06-14
# 893                        Cider       $1B  2021-09-02
# 980                         NIUM       $1B  2021-07-13
# 986                          ONE       $1B  2021-12-08
# 994                      PatSnap       $1B  2021-03-16
# 1061                       WeLab       $1B  2017-11-08
#
# ...

# %%
df[df['Select_Investors'] == 'Unknown']
# Out:
#               Company Valuation Date_joined                     Industry  \
# 629  LinkSure Network       $1B  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year_Founded Funding Select_Investors
# 629  Shanghai   China      Asia          2013    $52M          Unknown

# %%
df.isnull().sum()
# Out:
# Company             0
# Valuation           0
# Date_joined         0
# Industry            0
# City                0
# Country             0
# Continent           0
# Year_Founded        0
# Funding             0
# Select_Investors    0
# dtype: int64

# %%
df['Valuation'].value_counts()
# Out:
# Valuation
# $1B      471
# $2B      248
# $3B      115
# $4B       72
# $5B       40
# $6B       26
# $7B       18
# $10B      15
# $8B       13
# $9B       10
# $12B      10
# $11B       7
# $13B       4
# $15B       4
# $100B      2
# $20B       2
# $32B       2
# $38B       2
# $40B       2
# $17B       1
# $14B       1
# $18B       1
# $22B       1
# $25B       1
# $27B       1
# $33B       1
# $39B       1
# $46B       1
# $95B       1
# $180B      1
# Name: count, dtype: int64

# %%
def convert_dollar_to_int(value):
    if value.endswith('B'):
        return int(value[1:-1]) * 1000000000  # Convert billion to integer
    else:
        return int(value[1:])  # Remove "$" and convert to integer
df['Valuation'] = df['Valuation'].apply(convert_dollar_to_int)

# %%
df['Valuation'].value_counts()
# Out:
# Valuation
# 1000000000      471
# 2000000000      248
# 3000000000      115
# 4000000000       72
# 5000000000       40
# 6000000000       26
# 7000000000       18
# 10000000000      15
# 8000000000       13
# 9000000000       10
# 12000000000      10
# 11000000000       7
# 13000000000       4
# 15000000000       4
# 100000000000      2
# 20000000000       2
# 32000000000       2
# 38000000000       2
# 40000000000       2
# 17000000000       1
# 14000000000       1
# 18000000000       1
# 22000000000       1
# 25000000000       1
# 27000000000       1
# 33000000000       1
# 39000000000       1
# 46000000000       1
# 95000000000       1
# 180000000000      1
# Name: count, dtype: int64

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df['Funding'].value_counts()
# Out:
# Funding
# $1B        60
# $2B        30
# Unknown    12
# $200M      12
# $4B         9
#            ..
# $717M       1
# $101M       1
# $19M        1
# $946M       1
# $620M       1
# Name: count, Length: 539, dtype: int64

# %%
df['Funding'] = df['Funding'].replace('Unknown', np.nan)

# %%
df[df['Funding'] == 'Unknown']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation, Date_joined, Industry, City, Country, Continent, Year_Founded, Funding, Select_Investors]
# Index: []

# %%
df['Funding'].value_counts()
# Out:
# Funding
# $1B      60
# $2B      30
# $200M    12
# $4B       9
# $3B       7
#          ..
# $717M     1
# $101M     1
# $19M      1
# $946M     1
# $620M     1
# Name: count, Length: 538, dtype: int64

# %%
df['Funding'].value_counts(dropna=False)
# Out:
# Funding
# $1B      60
# $2B      30
# NaN      12
# $200M    12
# $4B       9
#          ..
# $717M     1
# $101M     1
# $19M      1
# $946M     1
# $620M     1
# Name: count, Length: 539, dtype: int64

# %%
def convert_dollar_to_int(value):
    if isinstance(value, str):
        value = value.replace('$', '')  # Remove "$" symbol
        if value.endswith('B'):
            return int(value[:-1]) * 1000000000  # Convert billion to integer
        elif value.endswith('M'):
            return int(value[:-1]) * 1000000  # Convert million to integer
        else:
            return int(value)  # Convert other numeric values to integer
    return value  # Return NaN values as they are

# Apply the conversion function to the 'Value' column
df['Funding'] = df['Funding'].apply(convert_dollar_to_int)

# Calculate the median of the integer values
median_value = df['Funding'].median()

# Replace NaN values with the median value
df['Funding'].fillna(median_value, inplace=True)

# %%
df['Funding'].value_counts()
# Out:
# Funding
# 1.000000e+09    60
# 2.000000e+09    30
# 3.700000e+08    15
# 2.000000e+08    12
# 4.000000e+09     9
#                 ..
# 7.170000e+08     1
# 1.010000e+08     1
# 1.900000e+07     1
# 9.460000e+08     1
# 6.200000e+08     1
# Name: count, Length: 538, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   int64
#  2   Date_joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1074 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year_Founded      1074 non-null   int64
#  8   Funding           1074 non-null   float64
#  9   Select_Investors  1074 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 84.0+ KB

# %%
df['Date_joined'] = pd.to_datetime(df['Date_joined'])
df['Year_Founded'] = pd.to_datetime(df['Year_Founded'], format='%Y')
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   int64
#  2   Date_joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1074 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year_Founded      1074 non-null   datetime64[ns]
#  8   Funding           1074 non-null   float64
#  9   Select_Investors  1074 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(6)
# memory usage: 84.0+ KB

# %%
df['%ROI'] = ((df['Valuation'] - df['Funding']) / df['Funding']) * 100

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df[['Company', 'Date_joined', 'Year_Founded']]
# Out:
#           Company Date_joined Year_Founded
# 0       Bytedance  2017-04-07   2012-01-01
# 1          SpaceX  2012-12-01   2002-01-01
# 2           SHEIN  2018-07-03   2008-01-01
# 3          Stripe  2014-01-23   2010-01-01
# 4          Klarna  2011-12-12   2005-01-01
# ...           ...         ...          ...
# 1069     Zhaogang  2017-06-29   2012-01-01
# 1070  Zhuan Zhuan  2017-04-18   2015-01-01
# 1071     Zihaiguo  2021-05-06   2018-01-01
# 1072         Zopa  2021-10-19   2005-01-01
# 1073        Zwift  2020-09-16   2014-01-01
#
# [1074 rows x 3 columns]

# %%
df['Days_to_Unicorn'] = df['Date_joined'] - df['Year_Founded']

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df[['Company', 'Days_to_Unicorn']]
# Out:
#           Company Days_to_Unicorn
# 0       Bytedance       1923 days
# 1          SpaceX       3987 days
# 2           SHEIN       3836 days
# 3          Stripe       1483 days
# 4          Klarna       2536 days
# ...           ...             ...
# 1069     Zhaogang       2006 days
# 1070  Zhuan Zhuan        838 days
# 1071     Zihaiguo       1221 days
# 1072         Zopa       6135 days
# 1073        Zwift       2450 days
#
# [1074 rows x 2 columns]

# %%
df[['Company', 'Days_to_Unicorn']].sort_values('Days_to_Unicorn')
# Out:
#                          Company Days_to_Unicorn
# 714                 Yidian Zixun      -1172 days
# 161        Ola Electric Mobility        182 days
# 1001                      Playco        264 days
# 396                    candy.com        293 days
# 554                   ClickHouse        300 days
# ...                          ...             ...
# 840     Radius Payment Solutions      10192 days
# 1043              Thirty Madison      10379 days
# 699   Five Star Business Finance      13599 days
# 373          Promasidor Holdings      13826 days
# 189         Otto Bock HealthCare      35969 days
#
# [1074 rows x 2 columns]

# %%
days_in_a_year = 365

# Convert the 'Timedelta_Days' column to years
df['Years_to_Unicorn'] = (df['Days_to_Unicorn'] / pd.Timedelta(days=days_in_a_year)).round(2)

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df[['Select_Investors']]
# Out:
#                                        Select_Investors
# 0     Sequoia Capital China, SIG Asia Investments, S...
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2     Tiger Global Management, Sequoia Capital China...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 4     Institutional Venture Partners, Sequoia Capita...
# ...                                                 ...
# 1069    K2 Ventures, Matrix Partners China, IDG Capital
# 1070                           58.com, Tencent Holdings
# 1071  Xingwang Investment Management, China Capital ...
# 1072  IAG Capital Partners, Augmentum Fintech, North...
# 1073    Novator Partners, True, Causeway Media Partners
#
# [1074 rows x 1 columns]

# %%
all_items = df['Select_Investors'].str.split(', ').explode()
item_counts = all_items.value_counts()

# %%
print(item_counts)
# Out:
# Select_Investors
# Accel                                      60
# Tiger Global Management                    53
# Andreessen Horowitz                        53
# Sequoia Capital China                      48
# Insight Partners                           47
#                                            ..
# GAM Holding                                 1
# HOF Capital                                 1
# People Electrical Appliance Group China     1
# Zhongrong International Trust               1
# Causeway Media Partners                     1
# Name: count, Length: 1259, dtype: int64

# %%
item_counts_df = pd.DataFrame({'Item': item_counts.index, 'Count': item_counts.values})

# %%
item_counts_df
# Out:
#                                          Item  Count
# 0                                       Accel     60
# 1                     Tiger Global Management     53
# 2                         Andreessen Horowitz     53
# 3                       Sequoia Capital China     48
# 4                            Insight Partners     47
# ...                                       ...    ...
# 1254                              GAM Holding      1
# 1255                              HOF Capital      1
# 1256  People Electrical Appliance Group China      1
# 1257            Zhongrong International Trust      1
# 1258                  Causeway Media Partners      1
#
# [1259 rows x 2 columns]

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   int64
#  2   Date_joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1074 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year_Founded      1074 non-null   datetime64[ns]
#  8   Funding           1074 non-null   float64
#  9   Select_Investors  1074 non-null   object
#  10  %ROI              1074 non-null   float64
#  11  Days_to_Unicorn   1074 non-null   timedelta64[ns]
#  12  Years_to_Unicorn  1074 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(6), timedelta64[ns](1)
# memory usage: 109.2+ KB

# %% [markdown]
# ### UNIVARIATE ANALYSIS

# %%
df.describe()
# Out:
#           Valuation                    Date_joined  \
# count  1.074000e+03                           1074
# mean   3.455307e+09  2020-05-19 15:35:51.955307264
# min    1.000000e+09            2007-07-02 00:00:00
# 25%    1.000000e+09            2019-05-20 06:00:00
# 50%    2.000000e+09            2021-03-29 00:00:00
# 75%    3.000000e+09            2021-09-19 18:00:00
# max    1.800000e+11            2022-04-05 00:00:00
# std    8.547022e+09                            NaN
#
#                         Year_Founded       Funding         %ROI  \
# count                           1074  1.074000e+03  1074.000000
# mean   2012-11-23 12:12:04.022346496  5.551769e+08          inf
# min              1919-01-01 00:00:00  0.000000e+00   -50.000000
# 25%              2011-01-01 00:00:00  2.240000e+08   241.589135
# 50%              2014-01-01 00:00:00  3.700000e+08   419.484024
# 75%              2016-01-01 00:00:00  6.030000e+08   717.578565
# ...

# %%
# top 10 valuation
top_Companies = df[['Company', 'Valuation']].sort_values('Valuation', ascending = False).head(10)
top_Companies
# Out:
#         Company     Valuation
# 0     Bytedance  180000000000
# 1        SpaceX  100000000000
# 2         SHEIN  100000000000
# 3        Stripe   95000000000
# 4        Klarna   46000000000
# 5         Canva   40000000000
# 6  Checkout.com   40000000000
# 7     Instacart   39000000000
# 8     JUUL Labs   38000000000
# 9    Databricks   38000000000

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
data = pd.DataFrame({
    'Company': ['Bytedance', 'SpaceX', 'SHEIN', 'Stripe', 'Klarna', 'Canva', 'Checkout.com', 'Instacart', 'JUUL Labs', 'Databricks'],
    'Valuation (Billions USD)': [180, 100, 100, 95, 46, 40, 40, 39, 38, 38]
})

# Sort data in descending order
data = data.sort_values('Valuation (Billions USD)', ascending=False)

# Generate gradient blue colors (reversed)
colors = np.linspace(1, 0, len(data))  # Reverse the order
colormap = plt.get_cmap('Blues')

# Create the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(data['Company'], data['Valuation (Billions USD)'], color=colormap(colors))

# Add data labels on top of the bars
for bar, val in zip(bars, data['Valuation (Billions USD)']):
    plt.text(bar.get_x() + bar.get_width() / 2, val + 3, f'{val}B', ha='center', va='bottom')

# Customize the chart
plt.title('Top 10 Valued Companies')
plt.xlabel('Company')
plt.ylabel('Valuation (Billions USD)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
data = pd.DataFrame({
    'Company': ['Bytedance', 'SpaceX', 'SHEIN', 'Stripe', 'Klarna', 'Canva', 'Checkout.com', 'Instacart', 'JUUL Labs', 'Databricks'],
    'Valuation (Billions USD)': [180, 100, 100, 95, 46, 40, 40, 39, 38, 38]
})

# Sort data in descending order
data = data.sort_values('Valuation (Billions USD)', ascending=True)

# Generate gradient blue colors
colors = np.linspace(0, 1, len(data))
colormap = plt.get_cmap('Blues')

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(data['Company'], data['Valuation (Billions USD)'], color=colormap(colors))

# Add data labels beside the bars
for bar, val in zip(bars, data['Valuation (Billions USD)']):
    plt.text(val + 3, bar.get_y() + bar.get_height() / 2, f'{val}B', va='center')

# Customize the chart
plt.title('Top 10 Valued Companies')
plt.xlabel('Valuation (Billions USD)')
plt.ylabel('Company')
plt.tight_layout()

# Show the chart
plt.show()

# %%
# Time to unicorn
mean_Days_to_Unicorn = df['Days_to_Unicorn'].mean()
df.loc[714, 'Days_to_Unicorn'] = mean_Days_to_Unicorn

# %%
days_to_unicorn = df[['Company', 'Days_to_Unicorn']].sort_values('Days_to_Unicorn', ascending = True).head(10)
days_to_unicorn
# Out:
#                     Company Days_to_Unicorn
# 161   Ola Electric Mobility        182 days
# 1001                 Playco        264 days
# 396               candy.com        293 days
# 554              ClickHouse        300 days
# 967            Mensa Brands        319 days
# 314              Flink Food        334 days
# 775                    Jokr        335 days
# 546                   Avant        351 days
# 822              GlobalBees        361 days
# 613                    EQRx        376 days

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data
data = pd.DataFrame({
    'Company': [
        'Ola Electric Mobility', 'Playco', 'candy.com', 'ClickHouse', 'Mensa Brands',
        'Flink Food', 'Jokr', 'Avant', 'GlobalBees', 'EQRx'
    ],
    'Days to Unicorn': [182, 264, 293, 300, 319, 334, 335, 351, 361, 376]
})

# Sort data in ascending order
data = data.sort_values('Days to Unicorn')

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(data['Company'], data['Days to Unicorn'], color='lightblue')

# Add data labels beside the bars
for bar, val in zip(bars, data['Days to Unicorn']):
    plt.text(val + 20, bar.get_y() + bar.get_height() / 2, f'{val} days', va='center')

# Customize the chart
plt.title('Top 10 Companies with Shortest Time to Unicorn')
plt.xlabel('Days to Unicorn')
plt.ylabel('Company')
plt.gca().invert_yaxis()  # Reverse the order to show the shortest time at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
# Top 10 cities with Unicorns
Top10_country = df['Country'].value_counts().head(10)
Top10_country
# Out:
# Country
# United States     562
# China             173
# India              65
# United Kingdom     43
# Germany            26
# France             24
# Israel             20
# Canada             19
# Brazil             16
# Singapore          12
# Name: count, dtype: int64

# %%
# Sample data (replace this with your Series)
Top10_country = pd.Series([562, 173, 65, 43, 26, 24, 20, 19, 16, 12],
                          index=['United States', 'China', 'India', 'United Kingdom', 'Germany', 'France', 'Israel', 'Canada', 'Brazil', 'Singapore'])

# Sort the data in descending order
Top10_country = Top10_country.sort_values(ascending=False)

# Define a fading (dark to light) color palette for bars
colors = sns.color_palette("Blues_r", n_colors=len(Top10_country))

# Create a custom bar chart with seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=Top10_country.values, y=Top10_country.index, palette=colors)

# Adding data labels to the bars
for i, v in enumerate(Top10_country):
    plt.text(v, i, f'{v}', va='center', fontsize=12)

# Adding labels and title
plt.xlabel('Number of Unicorns')
plt.ylabel('Country')
plt.title('Top 10 Countries with the Most Unicorns')

# Show the chart
plt.tight_layout()
plt.show()

# %%
import plotly.express as px

# Sample data (replace this with your Series)
Top10_country = pd.Series([562, 173, 65, 43, 26, 24, 20, 19, 16, 12],
                          index=['United States', 'China', 'India', 'United Kingdom', 'Germany', 'France', 'Israel', 'Canada', 'Brazil', 'Singapore'])

# Create a DataFrame from the Series
df_top10 = pd.DataFrame({'Country': Top10_country.index, 'Unicorn Count': Top10_country.values})

# Create an interactive map using Plotly
fig = px.scatter_geo(df_top10, locations="Country", locationmode="country names", color="Unicorn Count",
                     text="Country", hover_name="Country", size="Unicorn Count",
                     projection="natural earth")

# Customize the map layout
fig.update_geos(showcoastlines=True, coastlinecolor="Black", showland=True, landcolor="white")
fig.update_layout(title="Top 10 Countries with the Most Unicorns")

# Show the interactive map
fig.show()
# Out:
# <div>                            <div id="3e089cc5-83e0-49fc-b1c4-de2b64b05671" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e089cc5-83e0-49fc-b1c4-de2b64b05671")) {                    Plotly.newPlot(                        "3e089cc5-83e0-49fc-b1c4-de2b64b05671",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Unicorn Count=%{marker.color}<br>Country=%{location}<extra></extra>","hovertext":["United States","China","India","United Kingdom","Germany","France","Israel","Canada","Brazil","Singapore"],"legendgroup":"","locationmode":"country names","locations":["United States","China","India","United Kingdom","Germany","France","Israel","Canada","Brazil","Singapore"],"marker":{"color":[562,173,65,43,26,24,20,19,16,12]
# ...

# %%
# Top 10 cities with Unicorns
Top10_city = df['City'].value_counts().head(10)
Top10_city
# Out:
# City
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
# Bengaluru         29
# Shenzhen          19
# Paris             19
# Palo Alto         18
# Berlin            17
# Name: count, dtype: int64

# %%
Top10_city = Top10_city.sort_values(ascending=True)

# Define a fading (light to dark) color palette for bars
colors = sns.color_palette("Blues", n_colors=len(Top10_city))

# Create a custom bar chart with data labels
plt.figure(figsize=(10, 6))
bars = plt.barh(Top10_city.index, Top10_city.values, color=colors)

# Adding data labels to the bars
for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2, f'{width}', ha='left', va='center')

# Adding labels and title
plt.xlabel('Number of Unicorns')
plt.ylabel('City')
plt.title('Top 10 Cities with the Most Unicorns')

# Show the chart
plt.tight_layout()
plt.show()

# %%
City_valuation = df.groupby('City')['Valuation'].sum().nlargest(10)

# %%
City_valuation
# Out:
# City
# San Francisco    724000000000
# Beijing          348000000000
# New York         233000000000
# London           178000000000
# Shenzhen         141000000000
# Bengaluru        107000000000
# Hawthorne        101000000000
# Shanghai          99000000000
# Boston            69000000000
# Stockholm         63000000000
# Name: Valuation, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
cities = ['San Francisco', 'Beijing', 'New York', 'London', 'Shenzhen', 'Bengaluru', 'Hawthorne', 'Shanghai', 'Boston', 'Stockholm']
valuations = [724, 348, 233, 178, 141, 107, 101, 99, 69, 63]  # Values are in billions

# Sort data in descending order
cities, valuations = zip(*sorted(zip(cities, valuations), key=lambda x: x[1], reverse=True))

# Create a reversed gradient of blue colors
colors = plt.cm.Blues(np.linspace(1, 0.3, 10))

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(cities, valuations, color=colors)

# Add data labels beside the bars in billions
for bar, val in zip(bars, valuations):
    plt.text(val + 5, bar.get_y() + bar.get_height() / 2, f'${val}B', va='center')

# Customize the chart
plt.title('Top 10 Cities by Valuation')
plt.xlabel('Valuation (Billions USD)')
plt.ylabel('City')
plt.gca().invert_yaxis()  # Reverse the order to show the highest valuation at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
# Top 10 industry with Unicorns
Top_industry = df['Industry'].value_counts().head(16)
Top_industry
# Out:
# Industry
# Fintech                                224
# Internet software & services           205
# E-commerce & direct-to-consumer        111
# Health                                  74
# Artificial intelligence                 73
# Other                                   58
# Supply chain, logistics, & delivery     57
# Cybersecurity                           50
# Data management & analytics             41
# Mobile & telecommunications             38
# Hardware                                34
# Auto & transportation                   31
# Edtech                                  28
# Consumer & retail                       25
# Travel                                  14
# Artificial Intelligence                 11
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
industries = [
    'Fintech', 'Internet software & services', 'E-commerce & direct-to-consumer', 'Health',
    'Artificial intelligence', 'Other', 'Supply chain, logistics, & delivery', 'Cybersecurity',
    'Data management & analytics', 'Mobile & telecommunications', 'Hardware', 'Auto & transportation',
    'Edtech', 'Consumer & retail', 'Travel', 
]

counts = [224, 205, 111, 74, 84, 58, 57, 50, 41, 38, 34, 31, 28, 25, 14]  # Count of unicorn companies

# Sort data in descending order
industries, counts = zip(*sorted(zip(industries, counts), key=lambda x: x[1], reverse=True))

# Generate gradient blue colors starting from the top
colors = plt.cm.Blues(np.linspace(1, 0.3, 10))

# Create the horizontal bar chart
plt.figure(figsize=(10, 8))
bars = plt.barh(industries, counts, color=colors)

# Add data labels beside the bars in billions
for bar, count in zip(bars, counts):
    plt.text(count + 5, bar.get_y() + bar.get_height() / 2, f'{count}', va='center')

# Customize the chart
plt.title('Top 16 Industries with Unicorn Companies')
plt.xlabel('Count of Unicorn Companies')
plt.ylabel('Industry')
plt.gca().invert_yaxis()  # Reverse the order to show the highest count at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
#Top Industry by valuation

# %%
df.groupby('Industry')['Valuation'].sum().nlargest(10)
# Out:
# Industry
# Fintech                                882000000000
# Internet software & services           595000000000
# E-commerce & direct-to-consumer        426000000000
# Artificial intelligence                361000000000
# Other                                  252000000000
# Health                                 198000000000
# Supply chain, logistics, & delivery    177000000000
# Data management & analytics            136000000000
# Cybersecurity                          129000000000
# Consumer & retail                      106000000000
# Name: Valuation, dtype: int64

# %%
# Data
industries = [
    'Fintech', 'Internet software & services', 'E-commerce & direct-to-consumer',
    'Artificial intelligence', 'Other', 'Health',
    'Supply chain, logistics, & delivery', 'Data management & analytics',
    'Cybersecurity', 'Consumer & retail'
]

valuations = [882, 595, 426, 361, 252, 198, 177, 136, 129, 106]  # Values are in billions of dollars

# Sort data in descending order
industries, valuations = zip(*sorted(zip(industries, valuations), key=lambda x: x[1], reverse=True))

# Generate a gradient of blue colors
colors = plt.cm.Blues(np.linspace(1, 0.3, 10))

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(industries, valuations, color=colors)

# Add data labels beside the bars in billions of dollars
for bar, val in zip(bars, valuations):
    plt.text(val + 5, bar.get_y() + bar.get_height() / 2, f'${val}B', va='center')

# Customize the chart
plt.title('Top 10 Industries by Valuation')
plt.xlabel('Valuation (Billions USD)')
plt.ylabel('Industry')
plt.gca().invert_yaxis()  # Reverse the order to show the highest valuation at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
#top investors

# %%
df[['Select_Investors']]
# Out:
#                                        Select_Investors
# 0     Sequoia Capital China, SIG Asia Investments, S...
# 1     Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2     Tiger Global Management, Sequoia Capital China...
# 3           Khosla Ventures, LowercaseCapital, capitalG
# 4     Institutional Venture Partners, Sequoia Capita...
# ...                                                 ...
# 1069    K2 Ventures, Matrix Partners China, IDG Capital
# 1070                           58.com, Tencent Holdings
# 1071  Xingwang Investment Management, China Capital ...
# 1072  IAG Capital Partners, Augmentum Fintech, North...
# 1073    Novator Partners, True, Causeway Media Partners
#
# [1074 rows x 1 columns]

# %%
all_items = df['Select_Investors'].str.split(', ').explode()
item_counts = all_items.value_counts()

# %%
item_counts.head(10)
# Out:
# Select_Investors
# Accel                          60
# Tiger Global Management        53
# Andreessen Horowitz            53
# Sequoia Capital China          48
# Insight Partners               47
# Sequoia Capital                47
# Lightspeed Venture Partners    34
# SoftBank Group                 34
# General Catalyst               33
# Index Ventures                 32
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
investors = [
    'Accel', 'Tiger Global Management', 'Andreessen Horowitz', 'Sequoia Capital China',
    'Insight Partners', 'Sequoia Capital', 'Lightspeed Venture Partners', 'SoftBank Group',
    'General Catalyst', 'Index Ventures'
]

investments = [60, 53, 53, 48, 47, 47, 34, 34, 33, 32]  # Values are in billions of dollars

# Sort data in descending order
investors, investments = zip(*sorted(zip(investors, investments), key=lambda x: x[1], reverse=True))

# Generate a gradient of blue colors
colors = plt.cm.Blues(np.linspace(1, 0.3, 10))

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(investors, investments, color=colors)

# Add data labels beside the bars in billions of dollars
for bar, val in zip(bars, investments):
    plt.text(val + 5, bar.get_y() + bar.get_height() / 2, f'{val}', va='center')

# Customize the chart
plt.title('Top 10 Investors by Investment (Billions USD)')
plt.xlabel('Investment (Billions USD)')
plt.ylabel('Investor')
plt.gca().invert_yaxis()  # Reverse the order to show the highest investment at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
#Top 10 Companies with the Highest ROI
ROI = df[['Company', '%ROI']].sort_values('%ROI', ascending = False).head(11)
ROI
# Out:
#                     Company          %ROI
# 189    Otto Bock HealthCare           inf
# 239                  Zapier  3.999000e+05
# 61                   Dunamu  1.257606e+04
# 792               Workhuman  1.101111e+04
# 361                    CFGI  1.042632e+04
# 743                  Manner  9.900000e+03
# 72          DJI Innovations  7.519048e+03
# 760             GalaxySpace  7.042857e+03
# 5                     Canva  6.893007e+03
# 368              Il Makiage  6.796552e+03
# 1012  Revolution Precrafted  6.566667e+03

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data
companies = [
    'Otto Bock HealthCare', 'Zapier', 'Dunamu', 'Workhuman', 'CFGI',
    'Manner', 'DJI Innovations', 'GalaxySpace', 'Canva', 'Il Makiage'
]

roi_values = [float('inf'), 399900, 12576.06, 11011.11, 10426.32, 9900, 7519.05, 7042.86, 6893.01, 6796.55]

# Sort data in descending order (excluding the "inf" value)
companies, roi_values = zip(*sorted(zip(companies, roi_values), key=lambda x: x[1], reverse=True))

# Remove the "inf" value and its corresponding company
companies = companies[1:]
roi_values = roi_values[1:]

# Generate a gradient of blue colors
colors = plt.cm.Blues(np.linspace(1, 0.3, 10))

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(companies, roi_values, color=colors)

# Add data labels beside the bars in dollars
for bar, val in zip(bars, roi_values):
    plt.text(val + 500, bar.get_y() + bar.get_height() / 2, f'{val:.2f}%', va='center')

# Customize the chart
plt.title('Top 10 Companies with the Highest ROI')
plt.xlabel('ROI')
plt.ylabel('Company')
plt.gca().invert_yaxis()  # Reverse the order to show the highest ROI at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
Industry_F = df.groupby('Industry')['Funding'].sum().nlargest(16)

# %%
Industry_F
# Out:
# Industry
# Fintech                                1.087360e+11
# E-commerce & direct-to-consumer        7.517700e+10
# Internet software & services           7.369500e+10
# Supply chain, logistics, & delivery    4.476300e+10
# Artificial intelligence                4.392500e+10
# Other                                  4.078400e+10
# Auto & transportation                  3.507400e+10
# Health                                 3.394400e+10
# Consumer & retail                      2.586200e+10
# Cybersecurity                          2.193200e+10
# Edtech                                 2.187500e+10
# Hardware                               2.138500e+10
# Data management & analytics            1.835100e+10
# Mobile & telecommunications            1.525400e+10
# Travel                                 1.262600e+10
# Artificial Intelligence                2.877000e+09
# Name: Funding, dtype: float64

# %%
# Data
industries = [
    'Fintech', 'E-commerce & direct-to-consumer', 'Internet software & services',
    'Supply chain, logistics, & delivery', 'Artificial intelligence', 'Other',
    'Auto & transportation', 'Health', 'Consumer & retail', 'Cybersecurity',
    'Edtech', 'Hardware', 'Data management & analytics',
    'Mobile & telecommunications', 'Travel'
]

funding_values = [
    108.736e9, 75.177e9, 73.695e9, 44.763e9, 4.680025e10, 40.784e9,
    35.074e9, 33.944e9, 25.862e9, 21.932e9, 21.875e9, 21.385e9,
    18.351e9, 15.254e9, 12.626e9
]

# Generate a gradient of blue colors
colors = plt.cm.Blues(np.linspace(0.3, 1, 16))

# Create the horizontal bar chart
plt.figure(figsize=(10, 8))
bars = plt.barh(industries, funding_values, color='lightblue')

# Add data labels beside the bars in billion dollars
for bar, val in zip(bars, funding_values):
    plt.text(val + 5, bar.get_y() + bar.get_height() / 2, f'${val}', va='center')

# Customize the chart
plt.title('Top 16 Industries by Funding (Billion USD)')
plt.xlabel('Funding (Billion USD)')
plt.ylabel('Industry')
plt.gca().invert_yaxis()  # Reverse the order to show the highest funding at the top
plt.tight_layout()

# Show the chart
plt.show()

# %%
# Time to Unicorn
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
Days = df[['Company', 'Days_to_Unicorn']].sort_values('Days_to_Unicorn', ascending = True).head(10)
Days
# Out:
#                     Company Days_to_Unicorn
# 161   Ola Electric Mobility        182 days
# 1001                 Playco        264 days
# 396               candy.com        293 days
# 554              ClickHouse        300 days
# 967            Mensa Brands        319 days
# 314              Flink Food        334 days
# 775                    Jokr        335 days
# 546                   Avant        351 days
# 822              GlobalBees        361 days
# 613                    EQRx        376 days

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data (replace this with your DataFrame)
Day = pd.DataFrame({
    'Company': ['Ola Electric Mobility', 'Playco', 'candy.com', 'ClickHouse', 'Mensa Brands',
                'Flink Food', 'Jokr', 'Avant', 'GlobalBees', 'EQRx'],
    'Days_to_Unicorn': [182, 264, 293, 300, 319, 334, 335, 351, 361, 376]
})

# Sort the data in descending order
Day = Day.sort_values(by='Days_to_Unicorn', ascending=True)

# Define a fading (dark to light) color palette for bars
colors = sns.color_palette("Blues_r", n_colors=len(Day))

# Create a custom bar chart with seaborn
plt.figure(figsize=(8, 10))  # Adjust the figure size for a vertical column chart
sns.barplot(x='Company', y='Days_to_Unicorn', data=Day, palette=colors)  # Swap x and y

# Adding data labels to the bars
for i, v in enumerate(Day['Days_to_Unicorn']):
    plt.text(i, v, f'{v} days', ha='center', fontsize=12)  # Adjust coordinates and alignment

# Adding labels and title
plt.xlabel('Company')
plt.ylabel('Days to Unicorn')
plt.title('Top 10 Companies with the Fastest Days to Unicorn')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45, ha='right')

# Show the chart
plt.tight_layout()
plt.show()

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
# Days to Unicorn by Funding
Day_Funding = df[['Days_to_Unicorn','Funding' ]].sort_values('Days_to_Unicorn', ascending = True).head(10)
Day_Funding
# Out:
#      Days_to_Unicorn       Funding
# 161         182 days  7.610000e+08
# 1001        264 days  1.400000e+08
# 396         293 days  1.000000e+08
# 554         300 days  3.000000e+08
# 967         319 days  2.180000e+08
# 314         334 days  1.000000e+09
# 775         335 days  4.300000e+08
# 546         351 days  6.580000e+08
# 822         361 days  1.850000e+08
# 613         376 days  7.000000e+08

# %%
# Sample data
data = {
    'Days_to_Unicorn': ['182 days', '264 days', '293 days', '300 days', '319 days', '334 days', '335 days', '351 days', '361 days', '376 days'],
    'Funding': [7.61e8, 1.4e8, 1e8, 3e8, 2.18e8, 1e9, 4.3e8, 6.58e8, 1.85e8, 7e8]
}

df1 = pd.DataFrame(data)

# Sort the data in descending order by 'Days_to_Unicorn'
df1 = df1.sort_values('Days_to_Unicorn', ascending=False)

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(df1['Days_to_Unicorn'], df1['Funding'] / 1e6, color='lightblue')  # Convert to millions USD

# Add data labels in millions USD
for bar, funding in zip(bars, df['Funding']):
    funding_in_millions = funding / 1e6  # Convert to millions
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{funding_in_millions} Million USD', ha='left', va='center', fontsize=10, color='black')

# Set chart title and labels
plt.title('Days to Unicorn by Funding')
plt.xlabel('Funding (Millions USD)')
plt.ylabel('Days to Unicorn')

plt.show()

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
df['Unicorn_Year'] = df['Date_joined'].dt.year

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...

# %%
count = df.groupby('Unicorn_Year')['Company'].count()

# %%
JoinedYear

# %%
data = {
    'Unicorn_Year': [2007, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'Company_Count': [1, 2, 4, 3, 13, 35, 21, 44, 103, 104, 108, 520, 116]
}

df2 = pd.DataFrame(data)

# Create a line graph
plt.figure(figsize=(10, 6))
plt.plot(df2['Unicorn_Year'], df2['Company_Count'], marker='o', color='b', linestyle='-', linewidth=2, markersize=8)

# Add labels and title
plt.title('Unicorn Count from 2007 to 2022')
plt.xlabel('Year')
plt.ylabel('Number of Companies')

# Add grid lines
plt.grid(True, linestyle='--', alpha=0.7)

# Customize the x-axis ticks for better readability
plt.xticks(df['Unicorn_Year'], rotation=45)

plt.show()

# %%
df
# Out:
#           Company     Valuation Date_joined                         Industry  \
# 0       Bytedance  180000000000  2017-04-07          Artificial intelligence
# 1          SpaceX  100000000000  2012-12-01                            Other
# 2           SHEIN  100000000000  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe   95000000000  2014-01-23                          Fintech
# 4          Klarna   46000000000  2011-12-12                          Fintech
# ...           ...           ...         ...                              ...
# 1069     Zhaogang    1000000000  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan    1000000000  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo    1000000000  2021-05-06                Consumer & retail
# 1072         Zopa    1000000000  2021-10-19                          Fintech
# 1073        Zwift    1000000000  2020-09-16  E-commerce & direct-to-consumer
#
# ...
